# %%
import csv
import pandas as pd
import numpy as np
import os
import tensorflow as tf

# %%
def read_reviews_from_file(file_path):
    with open(file_path, 'r') as file:
        reviews = file.readlines()
    return [line.strip().split("\t") for line in reviews]

# %% [markdown]
# **Fetch all the reviews from these three files and add it in one list named reviews.**

# %%
current_directory = os.getcwd()

imdb_review = os.path.join(current_directory, "imdb_labelled.txt")
yelp_review = os.path.join(current_directory, "yelp_labelled.txt")
amazon_review = os.path.join(current_directory, "amazon_cells_labelled.txt")

reviews = []
reviews.extend(read_reviews_from_file(imdb_review))
reviews.extend(read_reviews_from_file(yelp_review))
reviews.extend(read_reviews_from_file(amazon_review))

# %%
csv_file = "reviews.csv"
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Review", "Label"])
    writer.writerows(reviews)

print("Reviews written to : ",csv_file)
# Out:
# Reviews written to :  reviews.csv

# %%
reviews = pd.read_csv(csv_file)
reviews
# Out:
#                                                  Review  Label
# 0     A very, very, very slow-moving, aimless movie ...      0
# 1     Not sure who was more lost - the flat characte...      0
# 2     Attempting artiness with black & white and cle...      0
# 3          Very little music or anything to speak of.        0
# 4     The best scene in the movie was when Gerardo i...      1
# ...                                                 ...    ...
# 2995  The screen does get smudged easily because it ...      0
# 2996  What a piece of junk.. I lose more calls on th...      0
# 2997                       Item Does Not Match Picture.      0
# 2998  The only thing that disappoint me is the infra...      0
# 2999  You can not answer calls with the unit, never ...      0
#
# [3000 rows x 2 columns]

# %%
total_row = reviews.shape[0]
count_null = reviews['Label'].isnull().sum()
filled_rows = total_row - count_null
if total_row==filled_rows:
    print("No Null Values")
else:
    print("Null Values!!! Kindly perform some preprocessing")
# Out:
# No Null Values

# %%
from tensorflow.keras.layers import SimpleRNN,Dense,Flatten
from tensorflow.keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from keras.utils import pad_sequences

# %% [markdown]
# 1.   Tokenization
# 2.   Convert text to int
# 3.   Generate sequence of integer for each sentences
# 4.   check the index of each word

# %%
tokenizer = Tokenizer(oov_token="out_of_vocabulary")

# %%
tokenizer.fit_on_texts(reviews['Review'])
reviews['Review'] = tokenizer.texts_to_sequences(reviews['Review'])
tokenizer.word_index
# Out:
# {'out_of_vocabulary': 1,
#  'the': 2,
#  'and': 3,
#  'i': 4,
#  'a': 5,
#  'is': 6,
#  'it': 7,
#  'to': 8,
#  'this': 9,
#  'of': 10,
#  'was': 11,
#  'in': 12,
#  'for': 13,
#  'not': 14,
#  'that': 15,
#  'with': 16,
#  'my': 17,
#  'very': 18,
#  'good': 19,
#  'on': 20,
#  'great': 21,
#  'you': 22,
#  'but': 23,
#  'have': 24,
#  'movie': 25,
#  'are': 26,
#  'as': 27,
#  'so': 28,
#  'phone': 29,
#  'film': 30,
#  'be': 31,
#  'all': 32,
#  'one': 33,
#  'had': 34,
#  'at': 35,
#  'food': 36,
#  'like': 37,
#  'just': 38,
#  "it's": 39,
#  'place': 40,
#  'time': 41,
#  'service': 42,
#  'an': 43,
#  'were': 44,
#  'if': 45,
#  'from': 46,
#  'really': 47,
#  'bad': 48,
#  'there': 49,
#  'they': 50,
#  'we': 51,
#  'well': 52,
#  'out': 53,
#  'has': 54,
#  'about': 55,
#  'would': 56,
#  'or': 57,
#  'no': 58,
#  'your': 59,
#  'only': 60,
#  'best': 61,
#  "don't": 62,
#  'by': 63,
#  'even': 64,
#  'ever': 65,
#  'here': 66,
#  'up': 67,
#  'also': 68,
#  'will': 69,
#  'back': 70,
#  'when': 71,
#  'me': 72,
#  'more': 73,
#  'than': 74,
#  'quality': 75,
#  'go': 76,
#  'what': 77,
#  'love': 78,
#  'he': 79,
#  'can': 80,
#  "i've": 81,
#  'made': 82,
#  'which': 83,
#  'because': 84,
#  'how': 85,
#  'work': 86,
#  'too': 87,
#  'product': 88,
#  'get': 89,
#  'some': 90,
#  'their': 91,
#  'works': 92,
#  'any': 93,
#  'better': 94,
#  'excellent': 95,
#  'do': 96,
#  'could': 97,
#  'nice': 98,
#  "i'm": 99,
#  'after': 100,
#  'never': 101,
#  'been': 102,
#  'much': 103,
#  'recommend': 104,
#  'sound': 105,
#  'who': 106,
#  'did': 107,
#  'again': 108,
#  'use': 109,
#  'our': 110,
#  'his': 111,
#  'other': 112,
#  'think': 113,
#  'first': 114,
#  'headset': 115,
#  'battery': 116,
#  'way': 117,
#  'them': 118,
#  'acting': 119,
#  'see': 120,
#  'pretty': 121,
#  'its': 122,
#  'make': 123,
#  "didn't": 124,
#  'most': 125,
#  'worst': 126,
#  'over': 127,
#  '2': 128,
#  'now': 129,
#  'still': 130,
#  'got': 131,
#  '10': 132,
#  'everything': 133,
#  'does': 134,
#  'enough': 135,
#  'say': 136,
#  'characters': 137,
#  'disappointed': 138,
#  'little': 139,
#  'two': 140,
#  'every': 141,
#  'am': 142,
#  'ear': 143,
#  'right': 144,
#  'these': 145,
#  'amazing': 146,
#  'going': 147,
#  'thing': 148,
#  'then': 149,
#  'being': 150,
#  'price': 151,
#  'waste': 152,
#  'people': 153,
#  'real': 154,
#  'definitely': 155,
#  'minutes': 156,
#  'off': 157,
#  'case': 158,
#  'terrible': 159,
#  'look': 160,
#  'money': 161,
#  'movies': 162,
#  'both': 163,
#  'experience': 164,
#  'know': 165,
#  'new': 166,
#  'came': 167,
#  'into': 168,
#  'friendly': 169,
#  'plot': 170,
#  'story': 171,
#  "doesn't": 172,
#  'her': 173,
#  'few': 174,
#  'many': 175,
#  'poor': 176,
#  'far': 177,
#  'life': 178,
#  'worth': 179,
#  'piece': 180,
#  'used': 181,
#  'long': 182,
#  'seen': 183,
#  'years': 184,
#  'nothing': 185,
#  "won't": 186,
#  'lot': 187,
#  'quite': 188,
#  'while': 189,
#  "can't": 190,
#  'want': 191,
#  'us': 192,
#  'wonderful': 193,
#  'restaurant': 194,
#  'films': 195,
#  'screen': 196,
#  'script': 197,
#  'she': 198,
#  'always': 199,
#  'happy': 200,
#  'camera': 201,
#  'anyone': 202,
#  'character': 203,
#  "wasn't": 204,
#  'give': 205,
#  'found': 206,
#  '1': 207,
#  'highly': 208,
#  'delicious': 209,
#  'another': 210,
#  'watching': 211,
#  'times': 212,
#  'down': 213,
#  'easy': 214,
#  'vegas': 215,
#  'loved': 216,
#  'buy': 217,
#  'take': 218,
#  'funny': 219,
#  'absolutely': 220,
#  'should': 221,
#  'however': 222,
#  'car': 223,
#  'awful': 224,
#  'probably': 225,
#  'around': 226,
#  'bought': 227,
#  'fine': 228,
#  'worked': 229,
#  'went': 230,
#  'slow': 231,
#  'thought': 232,
#  'since': 233,
#  'stars': 234,
#  'big': 235,
#  'same': 236,
#  'before': 237,
#  'horrible': 238,
#  'awesome': 239,
#  'comfortable': 240,
#  'item': 241,
#  'music': 242,
#  'find': 243,
#  'those': 244,
#  'cool': 245,
#  'where': 246,
#  'scenes': 247,
#  'totally': 248,
#  'actors': 249,
#  'things': 250,
#  'watch': 251,
#  'end': 252,
#  'show': 253,
#  '5': 254,
#  'makes': 255,
#  'impressed': 256,
#  'staff': 257,
#  'eat': 258,
#  'charger': 259,
#  'part': 260,
#  'cast': 261,
#  'though': 262,
#  'overall': 263,
#  'night': 264,
#  'must': 265,
#  "couldn't": 266,
#  'such': 267,
#  'last': 268,
#  'job': 269,
#  'talk': 270,
#  'cheap': 271,
#  'day': 272,
#  'old': 273,
#  'come': 274,
#  'fantastic': 275,
#  'small': 276,
#  'bluetooth': 277,
#  'black': 278,
#  'perfect': 279,
#  'beautiful': 280,
#  'kind': 281,
#  'family': 282,
#  'line': 283,
#  'stupid': 284,
#  'said': 285,
#  'feel': 286,
#  'chicken': 287,
#  'ordered': 288,
#  'reception': 289,
#  'sure': 290,
#  'low': 291,
#  'actually': 292,
#  'especially': 293,
#  'problem': 294,
#  'try': 295,
#  'fresh': 296,
#  "i'd": 297,
#  'performance': 298,
#  'done': 299,
#  'next': 300,
#  'special': 301,
#  'avoid': 302,
#  'anything': 303,
#  'scene': 304,
#  'bit': 305,
#  'simply': 306,
#  'least': 307,
#  'hard': 308,
#  'interesting': 309,
#  'between': 310,
#  'working': 311,
#  'felt': 312,
#  'year': 313,
#  '3': 314,
#  'coming': 315,
#  'problems': 316,
#  'sucks': 317,
#  'menu': 318,
#  'tried': 319,
#  'salad': 320,
#  'customer': 321,
#  'order': 322,
#  'pizza': 323,
#  'charge': 324,
#  'man': 325,
#  'almost': 326,
#  'fit': 327,
#  'away': 328,
#  'enjoyed': 329,
#  'liked': 330,
#  'writing': 331,
#  'worse': 332,
#  'without': 333,
#  'completely': 334,
#  'either': 335,
#  'everyone': 336,
#  'each': 337,
#  'gets': 338,
#  'looks': 339,
#  'calls': 340,
#  'expect': 341,
#  'hear': 342,
#  'taste': 343,
#  'fast': 344,
#  'wait': 345,
#  'steak': 346,
#  'purchase': 347,
#  'cell': 348,
#  'white': 349,
#  'through': 350,
#  'art': 351,
#  "i'll": 352,
#  'rather': 353,
#  'short': 354,
#  'dialogue': 355,
#  'hour': 356,
#  'fact': 357,
#  'left': 358,
#  'whole': 359,
#  'call': 360,
#  'super': 361,
#  'different': 362,
#  'seriously': 363,
#  'bland': 364,
#  'using': 365,
#  'clear': 366,
#  'server': 367,
#  'sushi': 368,
#  'flavor': 369,
#  'device': 370,
#  'saw': 371,
#  'buffet': 372,
#  'put': 373,
#  'crap': 374,
#  'play': 375,
#  'enjoy': 376,
#  "that's": 377,
#  'having': 378,
#  'feeling': 379,
#  'looking': 380,
#  'extremely': 381,
#  'disappointing': 382,
#  'understand': 383,
#  'several': 384,
#  'believe': 385,
#  'watched': 386,
#  'unfortunately': 387,
#  'sucked': 388,
#  'took': 389,
#  'incredible': 390,
#  'full': 391,
#  'tell': 392,
#  'started': 393,
#  'three': 394,
#  'return': 395,
#  'side': 396,
#  'may': 397,
#  'perfectly': 398,
#  'deal': 399,
#  'getting': 400,
#  'design': 401,
#  'plug': 402,
#  'atmosphere': 403,
#  'burger': 404,
#  'volume': 405,
#  'motorola': 406,
#  'hours': 407,
#  'certainly': 408,
#  'mediocre': 409,
#  'ending': 410,
#  'boring': 411,
#  'during': 412,
#  'oh': 413,
#  'need': 414,
#  'disappointment': 415,
#  'high': 416,
#  'barely': 417,
#  'truly': 418,
#  "there's": 419,
#  'received': 420,
#  'soon': 421,
#  'care': 422,
#  'yet': 423,
#  'less': 424,
#  'huge': 425,
#  'once': 426,
#  'light': 427,
#  'hot': 428,
#  'mess': 429,
#  'hands': 430,
#  'wrong': 431,
#  'stay': 432,
#  'tasty': 433,
#  'meal': 434,
#  'fits': 435,
#  'wasted': 436,
#  'kids': 437,
#  'predictable': 438,
#  'cinematography': 439,
#  'easily': 440,
#  'something': 441,
#  'together': 442,
#  'picture': 443,
#  'series': 444,
#  'strong': 445,
#  'fun': 446,
#  'effects': 447,
#  'glad': 448,
#  'actor': 449,
#  'voice': 450,
#  'gave': 451,
#  'played': 452,
#  'director': 453,
#  'why': 454,
#  'own': 455,
#  'drama': 456,
#  'pleased': 457,
#  'top': 458,
#  'star': 459,
#  'original': 460,
#  'recommended': 461,
#  'kept': 462,
#  'none': 463,
#  'home': 464,
#  'inside': 465,
#  'cold': 466,
#  'days': 467,
#  'selection': 468,
#  'prices': 469,
#  'sauce': 470,
#  'lunch': 471,
#  'breakfast': 472,
#  'waited': 473,
#  'area': 474,
#  'months': 475,
#  'phones': 476,
#  'lost': 477,
#  'half': 478,
#  'trying': 479,
#  'guess': 480,
#  'face': 481,
#  'directing': 482,
#  'making': 483,
#  'game': 484,
#  'tv': 485,
#  'decent': 486,
#  'horror': 487,
#  'house': 488,
#  'myself': 489,
#  'seems': 490,
#  'playing': 491,
#  'world': 492,
#  'cannot': 493,
#  'keep': 494,
#  'self': 495,
#  'free': 496,
#  'wanted': 497,
#  'him': 498,
#  'junk': 499,
#  'check': 500,
#  'turn': 501,
#  'places': 502,
#  'waitress': 503,
#  'set': 504,
#  'second': 505,
#  'couple': 506,
#  'under': 507,
#  '20': 508,
#  'style': 509,
#  'ago': 510,
#  'spot': 511,
#  'dropped': 512,
#  'broke': 513,
#  'eating': 514,
#  'fries': 515,
#  'table': 516,
#  'sandwich': 517,
#  'company': 518,
#  'meat': 519,
#  'helpful': 520,
#  'dishes': 521,
#  'clean': 522,
#  'priced': 523,
#  'bar': 524,
#  'wear': 525,
#  'amazon': 526,
#  'today': 527,
#  'average': 528,
#  'cinema': 529,
#  'important': 530,
#  'mind': 531,
#  'ask': 532,
#  'amount': 533,
#  'entire': 534,
#  'point': 535,
#  'told': 536,
#  'itself': 537,
#  'perhaps': 538,
#  'obviously': 539,
#  'waiting': 540,
#  'let': 541,
#  'twice': 542,
#  "wouldn't": 543,
#  'suspense': 544,
#  'given': 545,
#  'word': 546,
#  'plus': 547,
#  'pictures': 548,
#  'hate': 549,
#  'mostly': 550,
#  'else': 551,
#  'fails': 552,
#  'someone': 553,
#  'human': 554,
#  'pay': 555,
#  'although': 556,
#  'garbage': 557,
#  '4': 558,
#  'comes': 559,
#  'value': 560,
#  'finally': 561,
#  'weak': 562,
#  'expected': 563,
#  'audio': 564,
#  'quick': 565,
#  'beer': 566,
#  'dish': 567,
#  'dining': 568,
#  'arrived': 569,
#  'quickly': 570,
#  'spicy': 571,
#  'rude': 572,
#  'tasted': 573,
#  'simple': 574,
#  'verizon': 575,
#  'buttons': 576,
#  'jabra': 577,
#  'unit': 578,
#  'lines': 579,
#  'non': 580,
#  'charm': 581,
#  'hilarious': 582,
#  'budget': 583,
#  'review': 584,
#  'single': 585,
#  'editing': 586,
#  'whatever': 587,
#  'written': 588,
#  'front': 589,
#  'book': 590,
#  'annoying': 591,
#  'needed': 592,
#  'classic': 593,
#  'bring': 594,
#  'maybe': 595,
#  'joy': 596,
#  'brilliant': 597,
#  'wife': 598,
#  'friends': 599,
#  'others': 600,
#  'possible': 601,
#  'beyond': 602,
#  'reasonable': 603,
#  'close': 604,
#  'john': 605,
#  "isn't": 606,
#  'action': 607,
#  'might': 608,
#  'solid': 609,
#  'hope': 610,
#  'location': 611,
#  'sick': 612,
#  'above': 613,
#  'subtle': 614,
#  'mention': 615,
#  'literally': 616,
#  'room': 617,
#  '8': 618,
#  'drive': 619,
#  'cable': 620,
#  '30': 621,
#  'course': 622,
#  'store': 623,
#  'comedy': 624,
#  'superb': 625,
#  'later': 626,
#  'heart': 627,
#  'tender': 628,
#  'served': 629,
#  'outside': 630,
#  'unless': 631,
#  'wall': 632,
#  'within': 633,
#  'overpriced': 634,
#  'warm': 635,
#  'waiter': 636,
#  'attentive': 637,
#  'cooked': 638,
#  'town': 639,
#  'ambiance': 640,
#  'management': 641,
#  'chips': 642,
#  'authentic': 643,
#  'feels': 644,
#  'week': 645,
#  'color': 646,
#  'loud': 647,
#  'headsets': 648,
#  'software': 649,
#  'internet': 650,
#  'useless': 651,
#  'nokia': 652,
#  'walked': 653,
#  'clever': 654,
#  'ridiculous': 655,
#  'running': 656,
#  'rest': 657,
#  'lacks': 658,
#  'casting': 659,
#  'adorable': 660,
#  'songs': 661,
#  'history': 662,
#  'flick': 663,
#  'idea': 664,
#  'joke': 665,
#  'blue': 666,
#  'despite': 667,
#  'lovely': 668,
#  'girl': 669,
#  'performances': 670,
#  'believable': 671,
#  'portrayal': 672,
#  'sat': 673,
#  'gives': 674,
#  'whether': 675,
#  "they're": 676,
#  'business': 677,
#  'terrific': 678,
#  'sometimes': 679,
#  'instead': 680,
#  'happened': 681,
#  'rent': 682,
#  'cases': 683,
#  'fish': 684,
#  'whatsoever': 685,
#  'features': 686,
#  'setting': 687,
#  'seem': 688,
#  'seemed': 689,
#  'below': 690,
#  'goes': 691,
#  'living': 692,
#  'hold': 693,
#  'etc': 694,
#  'holes': 695,
#  'considering': 696,
#  'note': 697,
#  'child': 698,
#  'rating': 699,
#  'memorable': 700,
#  'sweet': 701,
#  'seeing': 702,
#  'particular': 703,
#  'exactly': 704,
#  'become': 705,
#  'leave': 706,
#  'throughout': 707,
#  'looked': 708,
#  'elsewhere': 709,
#  'reason': 710,
#  'reviews': 711,
#  'player': 712,
#  'wow': 713,
#  'lots': 714,
#  'poorly': 715,
#  'dont': 716,
#  'bother': 717,
#  'longer': 718,
#  'costs': 719,
#  'until': 720,
#  "you're": 721,
#  'hand': 722,
#  'rare': 723,
#  'range': 724,
#  'basically': 725,
#  'dead': 726,
#  'damn': 727,
#  'feature': 728,
#  'pho': 729,
#  'shrimp': 730,
#  'potato': 731,
#  'extra': 732,
#  'hit': 733,
#  'bars': 734,
#  'zero': 735,
#  'lacking': 736,
#  'large': 737,
#  'dinner': 738,
#  'mistake': 739,
#  'thin': 740,
#  'plastic': 741,
#  'ears': 742,
#  'headphones': 743,
#  'signal': 744,
#  'difficult': 745,
#  'samsung': 746,
#  'moving': 747,
#  'flat': 748,
#  'audience': 749,
#  'empty': 750,
#  'person': 751,
#  'consider': 752,
#  'production': 753,
#  '\x96': 754,
#  'minute': 755,
#  'level': 756,
#  'form': 757,
#  'graphics': 758,
#  'deserves': 759,
#  'lame': 760,
#  'rated': 761,
#  'choice': 762,
#  'fall': 763,
#  'utterly': 764,
#  'tom': 765,
#  'reading': 766,
#  'often': 767,
#  'generally': 768,
#  'shots': 769,
#  "aren't": 770,
#  'mouth': 771,
#  'wind': 772,
#  'turned': 773,
#  'list': 774,
#  'trip': 775,
#  'embarrassing': 776,
#  'wish': 777,
#  'along': 778,
#  'direction': 779,
#  'imagination': 780,
#  'cult': 781,
#  'incredibly': 782,
#  '7': 783,
#  'mean': 784,
#  'lead': 785,
#  'silent': 786,
#  "you'll": 787,
#  'owned': 788,
#  'provided': 789,
#  'hitchcock': 790,
#  'total': 791,
#  'thriller': 792,
#  'usual': 793,
#  'themselves': 794,
#  'recently': 795,
#  'pathetic': 796,
#  'lacked': 797,
#  'plain': 798,
#  'soundtrack': 799,
#  'trash': 800,
#  'offers': 801,
#  'fans': 802,
#  'eyes': 803,
#  'water': 804,
#  'shot': 805,
#  'games': 806,
#  'dry': 807,
#  "haven't": 808,
#  'cute': 809,
#  'roles': 810,
#  'cover': 811,
#  'fan': 812,
#  'cant': 813,
#  'involved': 814,
#  'period': 815,
#  "you'd": 816,
#  'particularly': 817,
#  'rate': 818,
#  'ended': 819,
#  'due': 820,
#  'recent': 821,
#  'par': 822,
#  'unbelievable': 823,
#  'computer': 824,
#  'forever': 825,
#  'holds': 826,
#  'sub': 827,
#  'impressive': 828,
#  'stuff': 829,
#  'ability': 830,
#  'touch': 831,
#  '40': 832,
#  'favorite': 833,
#  'sad': 834,
#  'asked': 835,
#  'tables': 836,
#  'portions': 837,
#  'sides': 838,
#  'dessert': 839,
#  'beef': 840,
#  'servers': 841,
#  'seafood': 842,
#  'pasta': 843,
#  'tasteless': 844,
#  'break': 845,
#  'party': 846,
#  'beat': 847,
#  'thai': 848,
#  'eaten': 849,
#  'thumbs': 850,
#  'seated': 851,
#  'reasonably': 852,
#  'bacon': 853,
#  'ice': 854,
#  'bread': 855,
#  'satisfied': 856,
#  'bargain': 857,
#  'please': 858,
#  'fried': 859,
#  'dirty': 860,
#  'buying': 861,
#  'options': 862,
#  'needs': 863,
#  'anytime': 864,
#  'ok': 865,
#  't': 866,
#  'leather': 867,
#  'razr': 868,
#  'charging': 869,
#  'mobile': 870,
#  'sturdy': 871,
#  'shipping': 872,
#  'weeks': 873,
#  'belt': 874,
#  'data': 875,
#  'clarity': 876,
#  'replace': 877,
#  'connection': 878,
#  'young': 879,
#  'nearly': 880,
#  'song': 881,
#  'head': 882,
#  'showed': 883,
#  'appealing': 884,
#  'main': 885,
#  'clearly': 886,
#  'tale': 887,
#  'greatest': 888,
#  'gem': 889,
#  'true': 890,
#  'words': 891,
#  'yes': 892,
#  'number': 893,
#  'massive': 894,
#  'rocks': 895,
#  'pg': 896,
#  'complete': 897,
#  'green': 898,
#  'cost': 899,
#  'addition': 900,
#  'convincing': 901,
#  'honestly': 902,
#  'follow': 903,
#  'energy': 904,
#  'pretentious': 905,
#  's': 906,
#  'run': 907,
#  'occasionally': 908,
#  'including': 909,
#  'somewhat': 910,
#  'advise': 911,
#  'chemistry': 912,
#  'fear': 913,
#  'q': 914,
#  'network': 915,
#  'passed': 916,
#  'depth': 917,
#  'bunch': 918,
#  'paid': 919,
#  'crazy': 920,
#  'storyline': 921,
#  'boyfriend': 922,
#  'gone': 923,
#  'five': 924,
#  '50': 925,
#  'already': 926,
#  'attempt': 927,
#  'torture': 928,
#  'pleasant': 929,
#  'premise': 930,
#  'missed': 931,
#  'ups': 932,
#  'age': 933,
#  'ray': 934,
#  'remember': 935,
#  'attention': 936,
#  'gotten': 937,
#  'visual': 938,
#  'called': 939,
#  'mexican': 940,
#  'indeed': 941,
#  'website': 942,
#  'thoroughly': 943,
#  'theater': 944,
#  'loves': 945,
#  'earlier': 946,
#  'directed': 947,
#  'intelligence': 948,
#  'intelligent': 949,
#  'sense': 950,
#  'entertaining': 951,
#  'genuine': 952,
#  'forget': 953,
#  'bored': 954,
#  'wonderfully': 955,
#  'guy': 956,
#  'likes': 957,
#  'shows': 958,
#  'towards': 959,
#  'drago': 960,
#  'enjoyable': 961,
#  '90': 962,
#  'parts': 963,
#  'sets': 964,
#  'effective': 965,
#  'stories': 966,
#  'son': 967,
#  'type': 968,
#  'created': 969,
#  'role': 970,
#  'ready': 971,
#  'scamp': 972,
#  'charming': 973,
#  'disgusting': 974,
#  'weird': 975,
#  'hated': 976,
#  'insult': 977,
#  'death': 978,
#  'rolls': 979,
#  'space': 980,
#  'share': 981,
#  '12': 982,
#  'doing': 983,
#  'power': 984,
#  'conclusion': 985,
#  'appearance': 986,
#  'ten': 987,
#  'final': 988,
#  'pull': 989,
#  'turns': 990,
#  'serious': 991,
#  'crowd': 992,
#  'killer': 993,
#  'james': 994,
#  'failed': 995,
#  'vibe': 996,
#  'dark': 997,
#  'honest': 998,
#  'christmas': 999,
#  'known': 1000,
#  ...}

# %%
reviews.head()
# Out:
#                                               Review  Label
# 0  [5, 18, 18, 18, 231, 747, 2268, 25, 55, 5, 226...      0
# 1  [14, 290, 106, 11, 73, 477, 2, 748, 137, 57, 2...      0
# 2  [2271, 2272, 16, 278, 349, 3, 654, 201, 1488, ...      0
# 3               [18, 139, 242, 57, 303, 8, 1094, 10]      0
# 4  [2, 61, 304, 12, 2, 25, 11, 71, 2274, 6, 479, ...      1

# %%
train_set, test_set = train_test_split(reviews,random_state=42,test_size=0.2)

# %%
X_train,Y_train = train_set['Review'],train_set['Label']
X_test,Y_test = test_set['Review'],test_set['Label']

# %%
max_len_review = max(len(review) for review in X_train)
min_len_review = min(len(review) for review in X_train)

print("Maximum length of review:", max_len_review)
print("Minimum length of review:", min_len_review)
# Out:
# Maximum length of review: 73
# Minimum length of review: 1

# %%
max_words = 60
X_train = pad_sequences(X_train,padding='post', maxlen=max_words)
X_test = pad_sequences(X_test,padding='post', maxlen=max_words)

# %%
X_valid, Y_valid = X_train[:256], Y_train[:256]
X_train_, Y_train_ = X_train[256:], Y_train[256:]

# %%
model = Sequential()
model.add(SimpleRNN(32,input_shape=(60,1),activation="tanh",return_sequences=False))
model.add(Dense(1,activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_5 (SimpleRNN)    (None, 32)                1088
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1121 (4.38 KB)
# Trainable params: 1121 (4.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile( loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train,batch_size=64,epochs=5,verbose=1,validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/5
# 38/38 [==============================] - 2s 18ms/step - loss: 0.6930 - accuracy: 0.5083 - val_loss: 0.6967 - val_accuracy: 0.4531
# Epoch 2/5
# 38/38 [==============================] - 0s 11ms/step - loss: 0.6925 - accuracy: 0.5154 - val_loss: 0.6936 - val_accuracy: 0.5234
# Epoch 3/5
# 38/38 [==============================] - 0s 11ms/step - loss: 0.6915 - accuracy: 0.5229 - val_loss: 0.6959 - val_accuracy: 0.5273
# Epoch 4/5
# 38/38 [==============================] - 0s 11ms/step - loss: 0.6926 - accuracy: 0.5083 - val_loss: 0.6920 - val_accuracy: 0.5508
# Epoch 5/5
# 38/38 [==============================] - 0s 11ms/step - loss: 0.6918 - accuracy: 0.5038 - val_loss: 0.6967 - val_accuracy: 0.5312

# %%
model.evaluate(X_test, Y_test, verbose=0)
# Out:
# [0.6923514008522034, 0.49666666984558105]
